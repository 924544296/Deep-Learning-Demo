# %% [markdown]
# #

# %% [markdown]
# # Generative Variational AutoEncoder for Real Image Super-Resolution
# ![figure1.png](attachment:figure1.png)

# %% [markdown]
# # Photo-Realistic Image Super-Resolution via Variational Autoencoders
# ![image.png](attachment:image.png)
